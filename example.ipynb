# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import ree_pvpc

# %%
ts = ree_pvpc.generate_series("20141129","20151129")

# %%
mean24 = pd.rolling_mean(ts, 24, center=True).dropna()
min24 = pd.rolling_min(ts, 24, center=True).dropna()
max24 = pd.rolling_max(ts, 24, center=True).dropna()
#ts.plot()
mean24.plot()
min24.plot()
max24.plot()
